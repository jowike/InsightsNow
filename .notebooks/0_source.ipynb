# %%
import pandas as pd

# %%
fred_variables = pd.read_excel(".datasets/FRED variables.xlsx", sheet_name="FRED American Variables")
first_release_dates = pd.read_excel(".datasets/FRED variables.xlsx", sheet_name="First Release Dates")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
source_data = pd.read_csv(".datasets/00_extract_vintagedata.csv", decimal=",")
# Out:
# /var/folders/3k/vh6dl_9j30z3n567nqndm7tw0000gp/T/ipykernel_73232/2370624844.py:1: DtypeWarning: Columns (2,8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   source_data = pd.read_csv(".datasets/00_extract_vintagedata.csv", decimal=",")

# %%
variable_codes = pd.concat([fred_variables["Variable code"].dropna(), first_release_dates["VariableCode"]]).drop_duplicates()

# %%
df_in = source_data.loc[source_data["VariableCode"].isin(variable_codes.to_list()+["WHLSLRIMSA"])]

# %%
df_in.to_parquet("/Users/ejowik001/Desktop/Github/InsightsNow/app/analytical-backend/data/0_source/fred_series_allvintagedates.parquet")
